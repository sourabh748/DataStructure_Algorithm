# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://research.cs.vt.edu/AVresearch/hashing/deletion.php <br>
# https://charlesreid1.com/wiki/Hash_Maps/Dynamic_Resizing <br>
# https://www.youtube.com/watch/T9gct6Dx-jo <br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
